# %%
from src.utils.helpers import read_json , show_image_plt

# %%
# !pip install matplotlib

# %%
annotations=read_json(r"data\tunisia-camera-shot-dataset-v1\tunisia-camera-shot-dataset\annotations.json")

# %%
(annotations[0])
# Out:
# {'local_path': 'E:/tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_1.jpg',
#  'relative_path': 'tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_1.jpg',
#  'class': 1}

# %%
import cv2
print('data/'+annotations[0]['relative_path'])
image =cv2.imread('C:/Users/DELL/pythonprojects/data/'+annotations[0]['relative_path'])
print('data/tunisia-camera-shot-dataset-v1'+annotations[0]['relative_path'])
image =cv2.imread('data/tunisia-camera-shot-dataset-v1/'+annotations[0]['relative_path'])
print(image.shape)

show_image_plt(image)
# Out:
# data/tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_1.jpg
# data/tunisia-camera-shot-dataset-v1tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_1.jpg
# (720, 1280, 3)

# %%
base_path ="data/tunisia-camera-shot-dataset-v1"
for idx, annot in enumerate(annotations):
    image_correct_path = f"{base_path}/{annot['relative_path']}"
    image = cv2.imread(image_correct_path)
    print(image.shape)
    print(image_correct_path ,annot['class'])
    image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    cv2.putText(image, f"class: {annot['class']}",(20, 40), cv2.FONT_HERSHEY_SIMPLEX,  2.0,(255, 0,0), 2,cv2.LINE_AA )
    show_image_plt(image)
    if idx>10 : break
# Out:
# (720, 1280, 3)
# data/tunisia-camera-shot-dataset-v1/tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_1.jpg 1
# (720, 1280, 3)
# data/tunisia-camera-shot-dataset-v1/tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_10.jpg 1
# (720, 1280, 3)
# data/tunisia-camera-shot-dataset-v1/tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_11.jpg 1
# (720, 1280, 3)
# data/tunisia-camera-shot-dataset-v1/tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_12.jpg 0
# (720, 1280, 3)
# data/tunisia-camera-shot-dataset-v1/tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_13.jpg 1
# (720, 1280, 3)
# data/tunisia-camera-shot-dataset-v1/tunisia-camera-shot-dataset/6431378b8296e3df0b54c129/6431378b8296e3df0b54c129_frame_14.jpg 1
# (720, 1280, 3)
# ...
